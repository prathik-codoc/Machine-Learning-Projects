# %% [markdown]
# <a href="https://colab.research.google.com/github/prathik-codoc/Machine-Learning-Projects/blob/main/8.%20Gold%20Price%20Prediction/Gold_Price_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Supervised learning
#
# Regression Model: Random Forest Regressor
