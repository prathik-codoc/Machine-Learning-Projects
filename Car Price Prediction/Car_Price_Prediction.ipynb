# %% [markdown]
# <a href="https://colab.research.google.com/github/prathik-codoc/Machine-Learning-Projects/blob/main/Car%20Price%20Prediction/Car_Price_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Supervised Learing:
# ## Regression Model:
# Linear & Lasso Regression Model
